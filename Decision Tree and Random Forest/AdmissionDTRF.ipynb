# %% [markdown]
# # Decision Tree and Random Forest

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Feb 16 18:29:00 2022

@author: Renee
"""
# Out:
# '\nCreated on Wed Feb 16 18:29:00 2022\n\n@author: Renee\n'

# %%
#import libraries
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn import tree

# %%
#load dataset
Admission = pd.read_csv('https://raw.githubusercontent.com/shenylin/Data-Science/main/Admission.csv')
print(Admission)
# Out:
#      GPA  GMAT  Decision
# 0   2.96   596         1
# 1   3.14   473         1
# 2   3.22   482         1
# 3   3.29   527         1
# 4   3.69   505         1
# 5   3.46   693         1
# 6   3.03   626         1
# 7   3.19   663         1
# 8   3.63   447         1
# 9   3.59   588         1
# 10  3.30   563         1
# 11  3.40   553         1
# 12  3.50   572         1
# 13  3.78   591         1
# 14  3.44   692         1
# 15  3.48   528         1
# 16  3.47   552         1
# 17  3.35   520         1
# 18  3.39   543         1
# 19  3.28   523         1
# 20  3.21   530         1
# 21  3.58   564         1
# 22  3.33   565         1
# 23  3.40   431         1
# 24  3.38   605         1
# 25  3.26   664         1
# 26  3.60   609         1
# 27  3.37   559         1
# 28  3.80   521         1
# 29  3.76   646         1
# 30  3.24   467         1
# 31  2.54   446         0
# 32  2.43   425         0
# 33  2.20   474         0
# 34  2.36   531         0
# 35  2.57   542         0
# ...

# %%
#Scatter Plot
#plt.scatter(Admission['GPA'], Admission['GMAT'])
#plt.xlabel('GPA')
#plt.ylabel('GMAT')
#plt.show()

#Normalize X
#min_max_scaler = MinMaxScaler()
#Admission[['GPA', 'GMAT']] = min_max_scaler.fit_transform(Admission[['GPA', 'GMAT']])
#print(Admission)

#Scatter Plot Normalized X
#plt.scatter(Admission['GPA'], Admission['GMAT'])
#plt.xlabel('GPA')
#plt.ylabel('GMAT')
#plt.show()

# %%
#Set Features and Target Variable
X = Admission[['GPA', 'GMAT']]
Y = Admission['Decision']

#Create classifier
clf = DecisionTreeClassifier(max_depth=3)
#clf = RandomForestClassifier(n_estimators=5)
clf.fit(X,Y)
Y_pred=clf.predict(X)

confusion_matrix = pd.crosstab(Y, Y_pred, rownames=['Actual'], colnames=['Predicted'])
sn.heatmap(confusion_matrix, annot=True)

print('Accuracy: ',metrics.accuracy_score(Y, Y_pred))
plt.show()

#print (X)
#print (Y_pred)

#prediction = clf.predict([[3.78, 591]]) 
#print ('Predicted Result: ', prediction)

importances = list(clf.feature_importances_)
# Print out the feature and importances 
print (importances)

#print(classification_report(Y, Y_pred))

fig = plt.figure(figsize=(12, 10))
tree.plot_tree(clf.fit(X,Y), class_names=['Yes', 'No'])
plt.show()
# Out:
# Accuracy:  1.0
# [1.0, 0.0]

# %%
#Set Features and Target Variable
X = Admission[['GPA', 'GMAT']]
Y = Admission['Decision']

#Create classifier
#clf = DecisionTreeClassifier(max_depth=3)
clf = RandomForestClassifier(n_estimators=5)
clf.fit(X,Y)
Y_pred=clf.predict(X)

confusion_matrix = pd.crosstab(Y, Y_pred, rownames=['Actual'], colnames=['Predicted'])
sn.heatmap(confusion_matrix, annot=True)

print('Accuracy: ',metrics.accuracy_score(Y, Y_pred))
plt.show()

#print (X)
#print (Y_pred)

#prediction = clf.predict([[3.78, 591]]) #This is an example of predicting a new value after running the learner.
#print ('Predicted Result: ', prediction)

importances = list(clf.feature_importances_)
# Print out the feature and importances 
print (importances)

#print(classification_report(Y, Y_pred))

fig = plt.figure(figsize=(12, 10))
tree.plot_tree(clf.fit(X,Y), class_names=['Yes', 'No'])
plt.show()
# Out:
# Accuracy:  1.0
# [0.7217892677402482, 0.27821073225975185]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-0a7fbc57b9a7> in <module>
#      28
#      29 fig = plt.figure(figsize=(12, 10))
# ---> 30 tree.plot_tree(clf.fit(X,Y), class_names=['Yes', 'No'])
#      31 plt.show()
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/tree/_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rotate, rounded, precision, ax, fontsize)
# ...
